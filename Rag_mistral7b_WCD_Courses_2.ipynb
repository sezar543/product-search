# %%
# Import necessary modules

import re
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

from huggingface_hub import HfApi, HfFolder
from langchain.retrievers import BM25Retriever, EnsembleRetriever
from langchain.retrievers.document_compressors import EmbeddingsFilter,LLMChainExtractor
from langchain.retrievers import ContextualCompressionRetriever
from langchain.document_loaders import WebBaseLoader, HuggingFaceDatasetLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings, OpenAIEmbeddings
from langchain_community.embeddings.huggingface import HuggingFaceEmbeddings

import os
import torch
from dotenv import load_dotenv, find_dotenv
from langchain_community.llms import HuggingFaceEndpoint, HuggingFaceHub
from langchain import HuggingFacePipeline
from langchain.schema import Document
from langchain_core.documents.base import Document
from langchain.vectorstores import Chroma

from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain.chains import RetrievalQA
from langchain.chains.retrieval_qa.base import RetrievalQA

from transformers import AutoModel, AutoTokenizer, AutoModelForQuestionAnswering, AutoModelForSequenceClassification , pipeline
from sentence_transformers import SentenceTransformer

# %%
def Extract_urls(sitemap_url): 
   response = requests.get(sitemap_url)
   sitemap_xml = response.content

   # Parse the sitemap
   soup = BeautifulSoup(sitemap_xml, "xml")

   # Extract all links
   links = []
   for link in soup.findAll("loc"):
       links.append(link.text)

   # Store the links in a variable
   urls = links
   urls=[url for url in urls if not (url.endswith(".png") or url.endswith(".jpg"))]
   #print(urls)
   return urls

# %%
sitemap = "https://weclouddata.com/sitemap_index.xml"

xmls=Extract_urls(sitemap)
#print('xmls = ',xmls)
all_urls=[]
for i,xml in enumerate(xmls):
    urls=Extract_urls(xmls[i])
    all_urls.append(urls)

#print(type(all_urls))
urls=all_urls[4]+all_urls[8]
print(len(urls),'urls = ',urls)
# Out:
# 38 urls =  ['https://weclouddata.com/courses/', 'https://weclouddata.com/courses/us-online/data-science-real-project-course/', 'https://weclouddata.com/courses/us-online/data-analytics-real-project-course/', 'https://weclouddata.com/courses/us-online/data-engineer-real-project-course/', 'https://weclouddata.com/courses/us-online/applied-machine-learning/', 'https://weclouddata.com/courses/us-online/big-data-for-data-scientist/', 'https://weclouddata.com/courses/us-online/data-science-with-python/', 'https://weclouddata.com/courses/online/ml-engineering-bootcamp/', 'https://weclouddata.com/courses/online/data-science-bootcamp-part-time/', 'https://weclouddata.com/courses/online/business-intelligence-bootcamp/', 'https://weclouddata.com/courses/us-online/data-fundamentals/', 'https://weclouddata.com/courses/us-online/analytics-engineering-course/', 'https://weclouddata.com/courses/us-online/ai-course-computer-vision/', 'https://weclouddata.com/courses/online/free-sql-course/', 'https://weclouddata.com/courses/online/free-python-course/', 'https://weclouddata.com/courses/us-online/ai-course-nlp-llm/', 'https://weclouddata.com/courses/us-online/mlops-engineering/', 'https://weclouddata.com/courses/us-online/devops-bootcamp-self-paced/', 'https://weclouddata.com/courses/us-online/data-science-bootcamp-self-paced/', 'https://weclouddata.com/courses/us-online/business-intelligence-bootcamp-self-paced/', 'https://weclouddata.com/courses/us-online/ml-engineering-bootcamp-self-paced/', 'https://weclouddata.com/courses/us-online/generative-ai-bootcamp-self-paced/', 'https://weclouddata.com/courses/us-online/data-engineering-bootcamp-self-paced/', 'https://weclouddata.com/courses/online/data-engineering-bootcamp-part-time/', 'https://weclouddata.com/courses/us-online/big-data-engineering/', 'https://weclouddata.com/courses/online/data-science-bootcamp/', 'https://weclouddata.com/course-package/devops-engineering-bootcamp-ca/', 'https://weclouddata.com/course-package/devops-engineering-bootcamp-us/', 'https://weclouddata.com/course-package/ml-engineering-bootcamp-ca/', 'https://weclouddata.com/course-package/ml-engineering-bootcamp-us/', 'https://weclouddata.com/course-package/business-intelligence-bootcamp-ca/', 'https://weclouddata.com/course-package/business-intelligence-bootcamp-us/', 'https://weclouddata.com/course-package/data-science-bootcamp-pt-us/', 'https://weclouddata.com/course-package/data-science-bootcamp-pt-ca/', 'https://weclouddata.com/course-package/data-engineering-bootcamp-ca/', 'https://weclouddata.com/course-package/data-engineering-bootcamp-us/', 'https://weclouddata.com/course-package/data-science-bootcamp-ft-ca/', 'https://weclouddata.com/course-package/data-science-bootcamp-ft-us/']

# %%
from dotenv import load_dotenv

# Load environment variables
load_dotenv('TokHap.env')
HUGGINGFACEHUB_API_TOKEN = os.environ["HUGGINGFACEHUB_API_TOKEN"]

# Set up the LLM from Hugging Face
repo_id = 'mistralai/Mistral-7B-Instruct-v0.2'
mistral_llm = HuggingFaceHub(repo_id=repo_id, model_kwargs={"temperature": 0.1, "max_new_tokens": 500})

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage
def load_clean_text_from_url(url):
  # Send a GET request to the webpage
  response = requests.get(url)

  # Check if the request was successful
  if response.status_code == 200:
      html_content = response.content

      # Parse the HTML content
      soup = BeautifulSoup(html_content, 'html.parser')
      # Find all body elements
      containers = soup.find_all('body')
      # Extract raw text for all body of Html
      for container in containers:
         raw_text = container.get_text(separator=' ', strip=True)
      # Clean the extracted text
      if raw_text:
         clean_text = ' '.join(raw_text.split())
         #print(clean_text)

  else:
     print("Failed to retrieve the webpage")

  return clean_text

# %%
#Create hierarchy headers tree
def create_hierarchy_header(headers):
    from collections import defaultdict

    def add_to_tree(tree, header, text):
        if header not in tree:
            tree[header] = {}
        tree = tree[header]
        return tree

    tree = {}
    levels = {'H1': 1, 'H2': 2, 'H3': 3, 'H4': 4, 'H5': 5 }
    current_path = []

    for header in headers:
        level, text = header.split(': ', 1)
        level_num = levels[level]

        while current_path and levels[current_path[-1][0]] >= level_num:
            current_path.pop()

        if current_path:
            subtree = current_path[-1][1]
        else:
            subtree = tree

        subtree = add_to_tree(subtree, header, text)
        current_path.append((level, subtree))

    return tree

# print tree of headers
def print_tree(tree, indent=0):
    for key, subtree in tree.items():
        print(' ' * indent + key)
        print_tree(subtree, indent + 4)


#hierarchy_headers = create_hierarchy_header(headers)
#print_tree(hierarchy_headers)

# %%
#headers = headers_final

def create_hierarchy_target_header(headers):
    def add_to_tree(tree, level, text):
        if (level, text) not in tree:
            tree[(level, text)] = {}
        return tree[(level, text)]

    tree = {}
    levels = {'H1': 1, 'H2': 2, 'H3': 3, 'H4': 4, 'H5': 5 }
    current_path = []

    for header in headers:
        level, text = header.split(': ', 1)
        level_num = levels[level]

        while current_path and levels[current_path[-1][0]] >= level_num:
            current_path.pop()

        if current_path:
            subtree = current_path[-1][1]
        else:
            subtree = tree

        subtree = add_to_tree(subtree, level, text)
        current_path.append((level, subtree))

    return tree

def find_path(tree, target, path=None):
    if path is None:
        path = []

    for (level, text), subtree in tree.items():
        new_path = path + [(level, text)]
        if text == target:
            return new_path
        found_path = find_path(subtree, target, new_path)
        if found_path:
            return found_path
    return None

# %%
# Create Hierarchical_Paths for all headers
def find_hierarchical_header_Paths(hierarchy,headers_text):
    Hierarchical_header_Paths=[]
    for target_header in headers_text:
        path_to_target = find_path(hierarchy, target_header)

        if path_to_target:
           path_as_string = " -> ".join(["{}: {}".format(level, text) for level, text in path_to_target])
           Hierarchical_header_Path = f"This content belongs to the following hierarchical headers path; {path_as_string} "
           Hierarchical_header_Paths.append(Hierarchical_header_Path)  
        else:
           print("Header '{}' not found".format(target_header))
    
    #print(len(Hierarchical_header_Paths),Hierarchical_header_Paths[20])
    return Hierarchical_header_Paths

# %%
# Extract Tution fee for every bootcamp
def find_amount_of_dollars(headers, path):
    # Determine currency based on title
    if 'us' in path.lower():
        currency = 'USD'
    elif 'ca' in path.lower():
        currency = 'CAD'
    else:
        currency = ''

    # Extract and format dollar amounts
    #Tuition = [f'${int(header)} {currency}' for header in headers if header.isdigit()]
    Tuition = ', '.join([f'${int(header)} {currency}' for header in headers if header.isdigit()])

    return Tuition

# %%
class Document:
    def __init__(self, page_content, metadata):
        self.page_content = page_content
        self.metadata = metadata

    def __repr__(self):
        return f"Document(page_content={self.page_content!r}, metadata={self.metadata!r})"


def is_word_at_start(text, word):
    # Strip any leading whitespace from the text and check if it starts with the word
    return text.strip().startswith(word)


def split_text_by_headers(text, headers):
    sections = []
    last_pos = 0
    for i, keyword in enumerate(headers):
        pos = text.find(keyword, last_pos)
        if pos != -1:
            if i > 0:
                sections.append(f" {text[last_pos:pos].strip()}")
            last_pos = pos
    sections.append(f" {text[last_pos:].strip()}")
    
    return sections

# %%
def load_headers_creat_metadata(url):

    data = []
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    page_title = soup.title.string if soup.title else 'No title found'
    path_segment = url.split(".com")[1]

    # Extracting all headers and content
    headers = soup.find_all(['h1', 'h2', 'h3', 'h4','h5'])
    
    for header in headers:
        header_tag = header.name.upper()
        header_text = header.get_text(strip=True)
        #header_text2 = header_text
        if header_text == "Drive Success with Interactive Learning Experience":
              header_text2 = header_text + " - Weekly Schedule "
        else:
              header_text2 = header_text

        header_final = f"{header_tag}: {header.get_text().strip()}"
        header_final2 = f"{header_tag}: {header_text2}"
        next_sibling = header.find_next_sibling()
        content = ''
        while next_sibling and next_sibling.name not in ['h1', 'h2', 'h3', 'h4','h5']:
            if next_sibling.name:
                content += next_sibling.get_text(strip=True) + " "
            next_sibling = next_sibling.find_next_sibling()
        
        data.append({
            'url': url,
            'path_segment': path_segment,
            'page_title': page_title,
            'header_tag' : header_tag,
            'header_text': header_text,
            'header_text2': header_text2,
            'header_final': header_final,
            'header_final2': header_final2,
            'content': content.strip()
        })

    #Convert to DataFrame and display
    df = pd.DataFrame(data)
    #df.head(20)
    headers_tag = df['header_tag'].tolist()
    headers_text = df['header_text'].tolist()
    headers_text2 = df['header_text2'].tolist()
    headers_final= df['header_final'].tolist()
    headers_final2= df['header_final2'].tolist()

    print(df.shape)

    text= load_clean_text_from_url(url)
    
    print('URL_link:', url)
    print("  ")
    #print(len(headers_final),'h=',headers_final)
    #print("<<<<---------->>>>")
    
    # Create hierarchy headers tree
    hierarchy_headers_tree = create_hierarchy_header(headers_final2)
    print_tree(hierarchy_headers_tree)
    print("<<<<--------------------------------------------------------------------->>>>")
    print()
    # Get the dollar amounts
    Tuition = find_amount_of_dollars(headers_text, path_segment)

    # Creating the hierarchical tree
    hierarchy = create_hierarchy_target_header(headers_final2)

    Hierarchical_header_Paths = find_hierarchical_header_Paths(hierarchy,headers_text2)

    result = split_text_by_headers(text, headers_text)
    #print('result_sec_num=',type(result),len(result))

    #header_fee_paths = []
    metadata_documents = []
    for i, section in enumerate(result):
        if is_word_at_start(section, headers_text[i]):
                       
           #section_extention = f" URL :: {url} \n Title :: {page_title} \n Link :: {path_segment}\n Section {i} ::{Hierarchical_header_Paths[i]} >> {headers_text[i]} >>>\n {section} "
            section_extention = f"Link :: {path_segment}\n Section {i} :: {Hierarchical_header_Paths[i]} >> {headers_text2[i]} >>> {section} "
            Hierarchical_header_Paths_S = Hierarchical_header_Paths[i]
            header_text_S = headers_text2[i]
        else:
           #section_extention=f" URL :: {url} \n Title :: {page_title} \n Link :: {path_segment}\n Section {i} ::{Hierarchical_header_Paths[i+1]} >> {headers_text[i+1]} >>>\n {section} "
            section_extention = f"Link :: {path_segment}\n Section {i} :: {Hierarchical_header_Paths[i+1]} >> {headers_text2[i+1]} >>> {section} "
            Hierarchical_header_Paths_S = Hierarchical_header_Paths[i+1]
            header_text_S = headers_text2[i+1]
    #print(section_extention)
    #print(">>>>>>>>>\n")
    
        metadata_documents.append(Document(
                    #page_content = section,
                    page_content = section_extention,
                    #page_content=f"Title :: {page_title}, Link :: {path_segment}, Section {i} :: {headers[i]} >>> {section} ",
                    metadata={"source": url,"Title": page_title, "hierarchical headers path": Hierarchical_header_Paths_S ,"Header": header_text_S, "Section number" :i }
                    ))


    header_fee_path = f"This content belongs to the following hierarchical headers of the tuition path; H1: {page_title} -> H5: Tuition Fee"
    #header_fee_paths.append(header_fee_path)
    metadata_documents.append(Document(
                    #page_content = section,
                    page_content = f"Link :: {path_segment} \n Section {i+1} :: {header_fee_path} >> Tuition Fee  >>>\n {Tuition} ",
                    #page_content=f"Title :: {page_title}, Link :: {path_segment}, Section {i} :: {headers[i]} >>> {section} ",
                    metadata={"source": url,"Title": page_title, "hierarchical headers path" : header_fee_path ,"Header":" Tuition Fee ", "Section number" :i+1 }
                    ))
    
    #print("i",i)
    #print("meta",len(metadata_documents))
    #print ('header=',result[0])
    return metadata_documents

# %%
# Load headers tree for all URLs and creat metadata documents
documents=[]
for url in urls:
    docs =[]
    docs=load_headers_creat_metadata(url)
    for doc in docs:
        documents.append(doc)
        #print(doc)
        #print("--------")
    
print(type(documents), len(documents))
#print(documents[17].page_content)
#print("-------------------------")
#print(documents[17].metadata)
# Out:
# (17, 9)
# URL_link: https://weclouddata.com/courses/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: All Programs and Courses
#     H4: Unsure which course to choose?
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
# <<<<--------------------------------------------------------------------->>>>
#
# (39, 9)
# URL_link: https://weclouddata.com/courses/us-online/data-science-real-project-course/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: Data Science Real Project Course
#     H4: About the Course
#         H5: Our alumni are working at
#     H2: Differentiation with Real Client Project Work
#         H4: Resources
#     H2: 1-1 career mentoring by real data experts
#     H2: Success Stories
#         H5: Full Tuition (Upfront)
#         H4: $10,000 (CAD) | $8,000 (USD)
#         H4: Speak to our advisor
#         H4: Admission Process
#             H5: Step 1
#             H5: Step 2
#             H5: Step 3
#             H5: Step 4
#         H4: Related Blog Posts
#         H4: Frequently Asked Questions
#         H4: Related Courses
#         H4: Data Engineer Real Project Course
#         H4: Business Intelligence Bootcamp
#         H4: Data Science Bootcamp
#             H5: Sign up for newsletter
#             H5: Programs
#             H5: Corporate Services
#             H5: Resources
#             H5: Company
#             H5: Let’s Connect!
#             H5: View our Data Science Real Project Course course package
#         H4: Data Science Real Project Course
#             H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (38, 9)
# URL_link: https://weclouddata.com/courses/us-online/data-analytics-real-project-course/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: Data Analytics Real Project Course
#     H4: About the Course
#         H5: Our alumni are working at
#     H2: Differentiation with Real Client Project Work
#         H4: Resources
#     H2: 1-1 career mentoring by real data experts
#     H2: Success Stories
#         H5: Full Tuition (Upfront)
#         H4: $10,000 (CAD) | $8,000 (USD)
#         H4: Speak to our advisor
#         H4: Admission Process
#             H5: Step 1
#             H5: Step 2
#             H5: Step 3
#             H5: Step 4
#         H4: Related Blog Posts
#         H4: Frequently Asked Questions
#         H4: Related Courses
#         H4: Business Intelligence Bootcamp
#         H4: Data Science Bootcamp
#             H5: Sign up for newsletter
#             H5: Programs
#             H5: Corporate Services
#             H5: Resources
#             H5: Company
#             H5: Let’s Connect!
#             H5: View our Data Analytics Real Project Course course package
#         H4: Data Analytics Real Project Course
#             H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (36, 9)
# URL_link: https://weclouddata.com/courses/us-online/data-engineer-real-project-course/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: Data Engineer Real Project Course
#     H4: About the Course
#         H5: Our alumni are working at
#     H2: Differentiation with Real Client Project Work
#         H4: Resources
#     H2: 1-1 career mentoring by real data experts
#     H2: Success Stories
#         H5: Full Tuition (Upfront)
#         H4: $10,000 (CAD) | $8,000 (USD)
#         H4: Speak to our advisor
#         H4: Admission Process
#             H5: Step 1
#             H5: Step 2
#             H5: Step 3
#             H5: Step 4
#         H4: Related Blog Posts
#         H4: Frequently Asked Questions
#         H4: Related Courses
#             H5: Sign up for newsletter
#             H5: Programs
#             H5: Corporate Services
#             H5: Resources
#             H5: Company
#             H5: Let’s Connect!
#             H5: View our Data Engineer Real Project Course course package
#         H4: Data Engineer Real Project Course
#             H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (37, 9)
# URL_link: https://weclouddata.com/courses/us-online/applied-machine-learning/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science
# H1: Applied Machine Learning
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: Portfolio Experience Building
#         H4: Upcoming Start Dates
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Applied Machine Learning course package
# <<<<--------------------------------------------------------------------->>>>
#
# (37, 9)
# URL_link: https://weclouddata.com/courses/us-online/big-data-for-data-scientist/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science
# H1: Big Data for Data Scientists
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: Portfolio Experience Building
#         H4: Upcoming Start Dates
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Big Data for Data Scientists course package
# <<<<--------------------------------------------------------------------->>>>
#
# (37, 9)
# URL_link: https://weclouddata.com/courses/us-online/data-science-with-python/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science
# H1: Data Science with Python
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: Portfolio Project Building
#         H4: Upcoming Start Dates
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Data Science with Python course package
# <<<<--------------------------------------------------------------------->>>>
#
# (69, 9)
# URL_link: https://weclouddata.com/courses/online/ml-engineering-bootcamp/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Machine Learning Engineering
# H1: Machine Learning Engineering Bootcamp
#     H4: About the Program
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H2: A path more than just courses
#         H4: Gain Hands-on Experience with Real-Client Projects
#         H4: Build real project experience to differentiate
#     H2: LEARNING EXPERIENCE
#         H4: Drive Success with Interactive Learning Experience - Weekly Schedule
#             H5: Bootcamp Journey
#         H4: Learn from the best instructors & TA
#         H4: Be ready for the new economy
#         H4: Upcoming Start Dates
#     H2: View Tuition, Financing Options, and Scholarship in the Program Package
#         H4: Career success takes more than just courses
#     H2: 1-on-1 Mentorship
#     H2: Networking & Community
#     H2: Events & Workshops
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#             H5: Celio Oliveira
#             H5: Minjung Koo
#             H5: Krittika Sarkar
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#         H4: Join our online webinar
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your application
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Machine Learning Engineering Bootcamp course package
#         H4: Machine Learning Engineering Bootcamp
#             H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (67, 9)
# URL_link: https://weclouddata.com/courses/online/data-science-bootcamp-part-time/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science
# H1: Data Science Bootcamp (Part-Time)
#     H4: About the Program
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H2: A path more than just courses
#         H4: Gain hands-on experience with Real-client Project
#         H4: Build real project experience to differentiate
#     H2: LEARNING EXPERIENCE
#         H4: Drive Success with Interactive Learning Experience - Weekly Schedule
#             H5: Bootcamp Journey
#         H4: Learn from the best instructors & TA
#         H4: Be ready for the new economy
#         H4: Upcoming Start Dates
#     H2: View Tuition, Financing Options, and Scholarship in the Program Package
#         H4: Career success takes more than just courses
#     H2: 1-on-1 Mentorship
#     H2: Networking & Community
#     H2: Events & Workshops
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#         H4: Join our online webinar
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your application
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Data Science Bootcamp (Part-Time) course package
#         H4: Data Science Bootcamp (Part-Time)
#             H5: Bootcamp Application
#             H5: Register for our webinar
# <<<<--------------------------------------------------------------------->>>>
#
# (69, 9)
# URL_link: https://weclouddata.com/courses/online/business-intelligence-bootcamp/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Business Intelligence
# H1: Business Intelligence Bootcamp
#     H4: About the Program
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H2: A path more than just courses
#         H4: Gain Hands-on Experience with Hands-on Projects
#         H4: Build real project experience to differentiate
#     H2: LEARNING EXPERIENCE
#         H4: Drive Success with Interactive Learning Experience - Weekly Schedule
#             H5: Bootcamp Journey
#         H4: Learn from the best instructors & TA
#         H4: Be ready for the new economy
#         H4: Upcoming Start Dates
#     H2: View Tuition, Financing Options, and Scholarship in the Program Package
#         H4: Career success takes more than just courses
#     H2: 1-on-1 Mentorship
#     H2: Networking & Community
#     H2: Events & Workshops
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#             H5: Davidson Dacleu
#             H5: Maryam Shakiba
#             H5: Joy Wang
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#         H4: Join our online webinar
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your application
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Business Intelligence Bootcamp course package
#         H4: Business Intelligence Bootcamp
#             H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (37, 9)
# URL_link: https://weclouddata.com/courses/us-online/data-fundamentals/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Business Intelligence,Data Engineering,Data Science
# H1: Data Fundamentals
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: Projects You Will Build in this Course
#         H4: Upcoming Start Dates
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Data Fundamentals course package
# <<<<--------------------------------------------------------------------->>>>
#
# (39, 9)
# URL_link: https://weclouddata.com/courses/us-online/analytics-engineering-course/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Engineering
# H1: Analytics Engineering Course
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: Portfolio Experience Building
#         H4: Upcoming Start Dates
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#             H5: Albert N.
#             H5: Anonymous Graduate, 2022
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Analytics Engineering Course course package
# <<<<--------------------------------------------------------------------->>>>
#
# (36, 9)
# URL_link: https://weclouddata.com/courses/us-online/ai-course-computer-vision/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Machine Learning Engineering
# H1: AI Course: Computer Vision
#     H4: About the Course
#     H3:
#         H4: WeCloudData is the perfect place to grow your career
#         H4: Ranked #1 Data Training Program
#         H4: Be ready for the new economy
#         H4: Learn from the best
#         H4: Upcoming Start Dates
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our AI Course: Computer Vision course package
# <<<<--------------------------------------------------------------------->>>>
#
# (35, 9)
# URL_link: https://weclouddata.com/courses/online/free-sql-course/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Business Intelligence,Data Engineering,Data Science
# H1: Free SQL Course
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: What are you going to learn in this course?
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Free SQL Course course package
# <<<<--------------------------------------------------------------------->>>>
#
# (35, 9)
# URL_link: https://weclouddata.com/courses/online/free-python-course/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Business Intelligence,Data Engineering,Data Science
# H1: Free Python Course
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: What are you going to learn in this course?
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Free Python Course course package
# <<<<--------------------------------------------------------------------->>>>
#
# (37, 9)
# URL_link: https://weclouddata.com/courses/us-online/ai-course-nlp-llm/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Machine Learning Engineering
# H1: AI Course: NLP/LLM
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: Portfolio Experience Building
#         H4: Upcoming Start Dates
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our AI Course: NLP/LLM course package
# <<<<--------------------------------------------------------------------->>>>
#
# (35, 9)
# URL_link: https://weclouddata.com/courses/us-online/mlops-engineering/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Machine Learning Engineering
# H1: MLOps Engineering
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H4: Upcoming Start Dates
#     H4: Explore your personalized learning path
#         H5: Have Questions?
#     H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our MLOps Engineering course package
# <<<<--------------------------------------------------------------------->>>>
#
# (57, 9)
# URL_link: https://weclouddata.com/courses/us-online/devops-bootcamp-self-paced/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: DevOps Engineering Bootcamp (Self-paced)
#     H5: Combine self-paced materials with mentor sessions for a comprehensive and flexible learning experience
#     H4: Access our comprehensive ✨self-paced✨ learning materials 24/7
#         H5: TA Support
#         H5: Real-World Applications
#     H4: About the Program
#         H5: What you will get
#         H5: Top data bootcamp voted by students and partners
#     H4: A Seamless and Enriching Learning Experience
#     H4: Explore Our Comprehensive Curriculum
#     H2: Nail your job search journey via 1-on-1 mentoring
#         H4: Get Job Ready with Hands-on Projects ✨
#         H4: Build real project experience to differentiate
#     H2: Tuition and Scholarship
#         H4: What our graduates are saying
#             H5: Celio Oliveira
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your career today!
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our DevOps Engineering Bootcamp (Self-paced) course package
#         H4: DevOps Engineering Bootcamp (Self-paced)
#             H5: Bootcamp Application
#             H5: View our DevOps Engineering Bootcamp (Self-paced) course package
# <<<<--------------------------------------------------------------------->>>>
#
# (56, 9)
# URL_link: https://weclouddata.com/courses/us-online/data-science-bootcamp-self-paced/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: Data Science Bootcamp (Self-paced)
#     H5: Combine self-paced materials with mentor sessions for a comprehensive and flexible learning experience
#     H4: Access our comprehensive ✨self-paced✨ learning materials 24/7
#         H5: TA Support
#         H5: Real-World Applications
#     H4: About the Program
#         H5: What you will get
#         H5: Top data bootcamp voted by students and partners
#     H4: A Seamless and Enriching Learning Experience
#     H4: Explore Our Comprehensive Curriculum
#     H2: Nail your job search journey via 1-on-1 mentoring
#         H4: Gain Hands-on Experience with Real-client Projects ✨
#         H4: Build real project experience to differentiate
#     H2: Tuition and Scholarship
#         H4: What our graduates are saying
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your career today!
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Data Science Bootcamp (Self-paced) course package
#         H4: Data Science Bootcamp (Self-paced)
#             H5: Bootcamp Application
#             H5: View our Data Science Bootcamp (Self-paced) course package
# <<<<--------------------------------------------------------------------->>>>
#
# (57, 9)
# URL_link: https://weclouddata.com/courses/us-online/business-intelligence-bootcamp-self-paced/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: Business Intelligence Bootcamp (Self-paced)
#     H5: Combine self-paced materials with mentor sessions for a comprehensive and flexible learning experience
#     H4: Access our comprehensive ✨self-paced✨ learning materials 24/7
#         H5: TA Support
#         H5: Real-World Applications
#     H4: About the Program
#         H5: What you will get
#         H5: Top data bootcamp voted by students and partners
#     H4: A Seamless and Enriching Learning Experience
#     H4: Explore Our Comprehensive Curriculum
#     H2: Nail your job search journey via 1-on-1 mentoring
#         H4: Gain Hands-on Experience with Hands-on Projects ✨
#         H4: Build real project experience to differentiate
#     H2: Tuition and Scholarship
#         H4: What our graduates are saying
#             H5: Davidson Dacleu
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your career today!
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Business Intelligence Bootcamp (Self-paced) course package
#         H4: Business Intelligence Bootcamp (Self-paced)
#             H5: Bootcamp Application
#             H5: View our Business Intelligence Bootcamp (Self-paced) course package
# <<<<--------------------------------------------------------------------->>>>
#
# (57, 9)
# URL_link: https://weclouddata.com/courses/us-online/ml-engineering-bootcamp-self-paced/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: Machine Learning Engineering Bootcamp (Self-paced)
#     H5: Combine self-paced materials with mentor sessions for a comprehensive and flexible learning experience
#     H4: Access our comprehensive ✨self-paced✨ learning materials 24/7
#         H5: TA Support
#         H5: Real-World Applications
#     H4: About the Program
#         H5: What you will get
#         H5: Top data bootcamp voted by students and partners
#     H4: A Seamless and Enriching Learning Experience
#     H4: Explore Our Comprehensive Curriculum
#     H2: Nail your job search journey via 1-on-1 mentoring
#         H4: Gain Hands-on Experience with Real-Client Projects ✨
#         H4: Build real project experience to differentiate
#     H2: Tuition and Scholarship
#         H4: What our graduates are saying
#             H5: Celio Oliveira
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your career today!
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Machine Learning Engineering Bootcamp (Self-paced) course package
#         H4: Machine Learning Engineering Bootcamp (Self-paced)
#             H5: Bootcamp Application
#             H5: View our Machine Learning Engineering Bootcamp (Self-paced) course package
# <<<<--------------------------------------------------------------------->>>>
#
# (55, 9)
# URL_link: https://weclouddata.com/courses/us-online/generative-ai-bootcamp-self-paced/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: Generative AI Bootcamp (Self-paced)
#     H5: Combine self-paced materials with mentor sessions for a comprehensive and flexible learning experience
#     H4: Access our comprehensive ✨self-paced✨ learning materials 24/7
#         H5: TA Support
#         H5: Real-World Applications
#     H4: About the Program
#         H5: What you will get
#         H5: Top data bootcamp voted by students and partners
#     H4: A Seamless and Enriching Learning Experience
#     H4: Explore Our Comprehensive Curriculum
#     H2: Nail your job search journey via 1-on-1 mentoring
#         H4: Build real project experience to differentiate
#     H2: Tuition and Scholarship
#         H4: What our graduates are saying
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your career today!
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Generative AI Bootcamp (Self-paced) course package
#         H4: Generative AI Bootcamp (Self-paced)
#             H5: Bootcamp Application
#             H5: View our Generative AI Bootcamp (Self-paced) course package
# <<<<--------------------------------------------------------------------->>>>
#
# (56, 9)
# URL_link: https://weclouddata.com/courses/us-online/data-engineering-bootcamp-self-paced/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H1: Data Engineering Bootcamp (Self-paced)
#     H5: Combine self-paced materials with mentor sessions for a comprehensive and flexible learning experience
#     H4: Access our comprehensive ✨self-paced✨ learning materials 24/7
#         H5: TA Support
#         H5: Real-World Applications
#     H4: About the Program
#         H5: What you will get
#         H5: Top data bootcamp voted by students and partners
#     H4: A Seamless and Enriching Learning Experience
#     H4: Explore Our Comprehensive Curriculum
#     H2: Nail your job search journey via 1-on-1 mentoring
#         H4: Gain Hands-on Experience with Real-client Projects ✨
#         H4: Build real project experience to differentiate
#     H2: Tuition and Scholarship
#         H4: What our graduates are saying
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your career today!
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Data Engineering Bootcamp (Self-paced) course package
#         H4: Data Engineering Bootcamp (Self-paced)
#             H5: Bootcamp Application
#             H5: View our Data Engineering Bootcamp (Self-paced) course package
# <<<<--------------------------------------------------------------------->>>>
#
# (68, 9)
# URL_link: https://weclouddata.com/courses/online/data-engineering-bootcamp-part-time/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Engineering
# H1: Data Engineering Bootcamp
#     H4: About the Program
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H2: A path more than just courses
#         H4: Gain Hands-on Experience with Real-client Projects
#         H4: Build real project experience to differentiate
#     H2: LEARNING EXPERIENCE
#         H4: Drive Success with Interactive Learning Experience - Weekly Schedule
#             H5: Bootcamp Journey
#         H4: Learn from the best instructors & TA
#         H4: Be ready for the new economy
#         H4: Upcoming Start Dates
#     H2: View Tuition, Financing Options, and Scholarship in the Program Package
#         H4: Career success takes more than just courses
#     H2: 1-on-1 Mentorship
#     H2: Networking & Community
#     H2: Events & Workshops
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#             H5: Albert N.
#             H5: Anonymous
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#         H4: Join our online webinar
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your application
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Data Engineering Bootcamp course package
#         H4: Data Engineering Bootcamp
#             H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (37, 9)
# URL_link: https://weclouddata.com/courses/us-online/big-data-engineering/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Engineering
# H1: Big Data Engineering
#     H4: About the Course
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H4: Be ready for the new economy
#     H4: Learn from the best
#     H2: Project
#         H4: Portfolio Experience Building
#         H4: Upcoming Start Dates
#         H4: Explore your personalized learning path
#             H5: Have Questions?
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Have questions?
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Big Data Engineering course package
# <<<<--------------------------------------------------------------------->>>>
#
# (67, 9)
# URL_link: https://weclouddata.com/courses/online/data-science-bootcamp/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science
# H1: Data Science Bootcamp
#     H4: About the Program
#     H4: WeCloudData is the perfect place to grow your career
#     H4: Ranked #1 Data Training Program
#     H2: A path more than just courses
#         H4: Gain Hands-on Experience with Real-client Projects
#         H4: Build real project experience to differentiate
#     H2: LEARNING EXPERIENCE
#         H4: Drive Success with Interactive Learning Experience - Weekly Schedule
#             H5: Bootcamp Journey
#         H4: Learn from the best instructors & TA
#         H4: Be ready for the new economy
#         H4: Upcoming Start Dates
#     H2: View Tuition, Financing Options, and Scholarship in the Program Package
#         H4: Career success takes more than just courses
#     H2: 1-on-1 Mentorship
#     H2: Networking & Community
#     H2: Events & Workshops
#         H4: Start Learning With WeCloudOpen
#     H2: WeCloudOpen Course
#     H2: WeCloudOpen Workshop
#         H4: What our graduates are saying
#             H5: Tony Li
#             H5: Gavin Ding
#             H5: Trisankur Bhuyan
#             H5: Vatsala Sharma
#             H5: Shima Sadat
#             H5: Lily Xiao
#             H5: Daniel Chil
#             H5: Yang Wu
#             H5: Waqas Khan
#             H5: Pooja Sureja
#             H5: Keivan Mokhtarpour
#             H5: Lynn Zhang
#             H5: Nikki Mihalovics
#             H5: Harold Castillo
#             H5: Chloe Dai
#             H5: Nathan Ling
#             H5: Shubhangi Kharat
#             H5: Varun Mehta
#             H5: Dipin Dilip
#             H5: Sally Li
#         H4: Join our online webinar
#     H2: Let WeCloud Accelerate Your Career in Tech
#         H5: Start your application
#         H5: Start learning with WeCloud Open
#     H2: FAQ
#         H5: Sign up for newsletter
#         H5: Programs
#         H5: Corporate Services
#         H5: Resources
#         H5: Company
#         H5: Let’s Connect!
#         H5: View our Data Science Bootcamp course package
#         H4: Data Science Bootcamp
#             H5: Bootcamp Application
#             H5: Register for our webinar
# <<<<--------------------------------------------------------------------->>>>
#
# (40, 9)
# URL_link: https://weclouddata.com/course-package/devops-engineering-bootcamp-ca/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: DevOps Engineering Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#     H3: $10000
#         H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join DevOps Engineering Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: DevOps Engineering Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (42, 9)
# URL_link: https://weclouddata.com/course-package/devops-engineering-bootcamp-us/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: DevOps Engineering Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#             H5: 7000
#             H5: 8000
#             H5: 12000
#             H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join DevOps Engineering Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: DevOps Engineering Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (40, 9)
# URL_link: https://weclouddata.com/course-package/ml-engineering-bootcamp-ca/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Machine Learning Engineering Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#     H3: $10000
#         H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Machine Learning Engineering Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Machine Learning Engineering Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (42, 9)
# URL_link: https://weclouddata.com/course-package/ml-engineering-bootcamp-us/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Machine Learning Engineering Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#             H5: 7000
#             H5: 8000
#             H5: 12000
#             H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Machine Learning Engineering Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Machine Learning Engineering Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (40, 9)
# URL_link: https://weclouddata.com/course-package/business-intelligence-bootcamp-ca/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Business Intelligence Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#     H3: $5600
#         H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Business Intelligence Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Business Intelligence Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (42, 9)
# URL_link: https://weclouddata.com/course-package/business-intelligence-bootcamp-us/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Business Intelligence Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#             H5: 4100
#             H5: 4500
#             H5: 10000
#             H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Business Intelligence Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Business Intelligence Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (42, 9)
# URL_link: https://weclouddata.com/course-package/data-science-bootcamp-pt-us/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#             H5: 7000
#             H5: 8000
#             H5: 12000
#             H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Data Science Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Data Science Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (40, 9)
# URL_link: https://weclouddata.com/course-package/data-science-bootcamp-pt-ca/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#     H3: $10000
#         H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Data Science Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Data Science Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (40, 9)
# URL_link: https://weclouddata.com/course-package/data-engineering-bootcamp-ca/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Engineering Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#     H3: $10000
#         H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Data Engineering Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Data Engineering Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (42, 9)
# URL_link: https://weclouddata.com/course-package/data-engineering-bootcamp-us/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Engineering Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#             H5: 7000
#             H5: 8000
#             H5: 12000
#             H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Data Engineering Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Data Engineering Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (40, 9)
# URL_link: https://weclouddata.com/course-package/data-science-bootcamp-ft-ca/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#     H3: $15400
#         H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Data Science Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Data Science Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# (42, 9)
# URL_link: https://weclouddata.com/course-package/data-science-bootcamp-ft-us/
#
# H5: Bootcamp Programs
# H5: Short Courses
# H5: Project Course
# H5: Learning Path
# H5: Corporate Partners
# H2: Corporate Training >
#     H3: DevOps >
#         H5: Resources
# H2: Blogs   >
# H2: Data Science Bootcamp
#     H5: Jump to section
# H2: Unlock Your Data Potential
#     H4: Upcoming Cohort
#     H4: Curriculum
#     H4: Application Process
#     H3: Book a Consultation Meeting
#     H3: Pass the Screening Test
#     H3: Accepted
#         H5: Ready to Apply?
#         H4: Tuition
#             H5: 9000
#             H5: 10000
#             H5: 12500
#             H5: Have Questions?
#         H4: Financing Options
#         H4: Scholarships
#         H4: Real-Client Project
#             H5: Ready to Apply?
#         H4: Career Services
#             H5: Ready to Apply?
#         H4: Try it out with WeCloudOpen
# H2: WeCloudOpen Course
# H2: WeCloudOpen Workshop
# H2: Join Data Science Bootcamp
#     H5: Sign up for newsletter
#     H5: Programs
#     H5: Corporate Services
#     H5: Resources
#     H5: Company
#     H5: Let’s Connect!
#     H4: Data Science Bootcamp
#         H5: Bootcamp Application
# <<<<--------------------------------------------------------------------->>>>
#
# <class 'list'> 1699

# %%
hierarchical_headers = []
for doc in documents:
    hierarchical_headers.append(doc.metadata['hierarchical headers path'])
    
#print(hierarchical_headers[17])           
print(len(hierarchical_headers))
# Out:
# 1699

# %%
# Find all documents that include a specific text or word
i=0
for txt in documents:
    x=["Weekly Schedule","Edwin","instructors","Tuition Fee","$10,000","instructors & TA"]
    tx=x[0]
    if tx in txt.page_content:
           #print(" ")
           #print(txt)
           #print("<<<----------------------------->>>")
           #print(txt.metadata)
           #print("->>>")
           #print(txt.metadata['hierarchical headers path'])
           #print("---------------")
           #print(txt.page_content)
           i=i+1
    
print(i)
# Out:
# 10

# %%
# Create an instance of the RecursiveCharacterTextSplitter class with specific parameters.
# It splits text into chunks of 1024 characters each with a 300-character overlap.
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1024, chunk_overlap=300)

# 'data' holds the text you want to split, split the text into documents using the text splitter.
chunks = text_splitter.split_documents(documents)

# Check the length of docs
print(len(chunks))


# Display the first split document
#print(chunks[19])
#print(chunks[19].metadata)
#print(chunks[19].page_content)
# Out:
# 2758

# %%
# Define the path to the pre-trained model you want to use
modelPath = "sentence-transformers/all-MiniLM-L6-v2"   #384
#modelPath = "sentence-transformers/all-mpnet-base-v2"   #768
#modelPath = "sentence-transformers/clips/mfaq"

# Create a dictionary with model configuration options, specifying to use the CPU for computations
model_kwargs = {'device': 'cpu'}

# Create a dictionary with encoding options, specifically setting 'normalize_embeddings' to True
encode_kwargs = {'normalize_embeddings': True}

# Initialize an instance of HuggingFaceEmbeddings with the specified parameters
embeddings = HuggingFaceEmbeddings(
    model_name=modelPath,     # Provide the pre-trained model's path
    model_kwargs=model_kwargs, # Pass the model configuration options
    encode_kwargs=encode_kwargs # Pass the encoding options
)

# %%
persist_directory="./courses.db"
db = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=persist_directory
)

print(db._collection.count())
#print(db._collection.get().keys())
#print(db.get('embedding')["embeddings"])
print((len(db.get(include=['embeddings'])['embeddings'][10])))
# Out:
# 105274
# 384

# %%
# 0-25
questions = [ 
"Who are the instructors for the Data Engineering Bootcamp?",   # 0
"What is the weekly schedule for the Data Engineering Bootcamp?",# 1
"What is the tuition for the Data Engineering Bootcamp",        # 2
"Is there a self paced data engineering bootcamp?",             # 3
"Are there any pre-requisites for enrolling in the Data Engineering Bootcamp?",# 4
"Can students participate in live sessions during the self paced courses?",    # 5
"What kind of mentorship is offered in the Data Science Bootcamp?",            # 6
"What kind of projects are included in the AI Course: NLP/LLM?",               # 7
"What are the differences between the Data Science with Python course and the Applied Machine Learning course?",# 8
"What kind of real-world applications are included in the Data Engineering curriculum?", # 9
"What kind of career support does WeCloudData offer to its students?",                   # 10
"What are the main differences between self paced courses and bootcamp programs at WeCloudData?",# 11
"What is the format of the TA support in self paced courses?",# 12
"What is the duration of the Business Intelligence Bootcamp?",# 13
"What is the focus of the DevOps Engineering Bootcamp?",      # 14
"Who are the instructors for the Data Science Bootcamp?",     # 15
"Who are the instructors for the Machine Learning Engineering Bootcamp?",   # 16
"What is the weekly schedule for the Data Science Bootcamp",                # 17
"What is the weekly schedule for the Machine Learning Engineering Bootcamp",# 18
"What is the tuition for the Data Science Bootcamp",    # 19
"What is the tuition for the Machine Learning Bootcamp",# 20
"Are there any pre-requisites for enrolling in the Data Science Bootcamp?", #21
"Are there any pre-requisites for the Machine Learning Bootcamp",           #22
"What kind of mentorship is offered in the Data Engineering Bootcamp?",     #23
"What kind of real-world applications are included in the Data Science curriculum?",     # 24
"What kind of real-world applications are included in the Machine Learning curriculum?"] # 25


query = questions[0]
print('query = ',query)
# Out:
# query =  Who are the instructors for the Data Engineering Bootcamp?

# %%
def contains_word(query, word):
    # Convert both the query and word to lowercase to make the check case-insensitive
    query_lower = query.lower()
    word_lower = word.lower()
    
    # Check if the word is in the query
    if word_lower in query_lower.split():
        return True
    else:
        return False

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Your query
query = query

if contains_word(query, "tuition"):

       hierarchical_headers=[
          'This content belongs to the following hierarchical headers of the tuition path; H1: Business Intelligence Bootcamp - WeCloudData -> H5: Tuition Fee',
          'This content belongs to the following hierarchical headers of the tuition path; H1: Data Science Bootcamp - WeCloudData -> H5: Tuition Fee',
          'This content belongs to the following hierarchical headers of the tuition path; H1: Data Engineering Bootcamp - WeCloudData -> H5: Tuition Fee',
          'This content belongs to the following hierarchical headers of the tuition path; H1: Machine Learning Engineering Bootcamp - WeCloudData -> H5: Tuition Fee']

# List of headers
headers = hierarchical_headers

# Combine headers and query into a single list
docs = headers + [query]

# Vectorize the documents
vectorizer = TfidfVectorizer().fit_transform(docs)
vectors = vectorizer.toarray()

# Compute cosine similarity between query and each header
cosine_similarities = cosine_similarity(vectors[-1].reshape(1, -1), vectors[:-1]).flatten()

# Find the index of the closest header
closest_header_index = np.argmax(cosine_similarities)

# Get the closest header
closest_header = headers[closest_header_index]


print(type(closest_header),closest_header)
# Out:
# <class 'str'> This content belongs to the following hierarchical headers path; H1: Data Engineering Bootcamp -> H2: LEARNING EXPERIENCE -> H4: Learn from the best instructors & TA

# %%
k= 6 #5,..,10  

print("------------ Retrieval filter based on hierarchical headers path ----------------")
#result1_ret = db.as_retriever(search_kwargs={'k': k,'filter': {'Title': 'Data Engineering Bootcamp - WeCloudData'}}, search_type = 'similarity').invoke(query)
#result1_ret = db.as_retriever(search_kwargs={'k': k,'filter': {'hierarchical headers path':'Hierarchical header Paths is H1: Data Engineering Bootcamp - WeCloudData -> H5: Tuition Fee'}}, search_type = 'mmr').invoke(query)
result1_ret = db.as_retriever(search_kwargs={'k': k,'filter': {'hierarchical headers path': f'{closest_header}'}}, search_type = 'mmr').invoke(query)
print("--Question   :  ",query)
#print("--Response   :  ",result1_ret)
#print(type(result1_ret))
for i in range(0,len(result1_ret)):
    #print(result1_ret[i].metadata)
    print(result1_ret[i].metadata['hierarchical headers path'])
print("  ")


print("------------ Retrieval without filter ----------------")
result2_ret = db.as_retriever(search_kwargs={"k": k}, search_type = 'mmr').invoke(query)
#result2_ret = db.as_retriever(search_kwargs={'k': k}, search_type = 'similarity').invoke(query)
print("--Question   :  ",query)
#print("--Response   :  ",result2_ret)
#print(type(result2_ret))
for i in range(0,len(result2_ret)):
    #print(result2_ret[i].metadata)
    print(result2_ret[i].metadata['hierarchical headers path'])
# Out:
# ------------ Retrieval filter based on hierarchical headers path ----------------
# --Question   :   Who are the instructors for the Data Engineering Bootcamp?
# This content belongs to the following hierarchical headers path; H1: Data Engineering Bootcamp -> H2: LEARNING EXPERIENCE -> H4: Learn from the best instructors & TA
# This content belongs to the following hierarchical headers path; H1: Data Engineering Bootcamp -> H2: LEARNING EXPERIENCE -> H4: Learn from the best instructors & TA
# This content belongs to the following hierarchical headers path; H1: Data Engineering Bootcamp -> H2: LEARNING EXPERIENCE -> H4: Learn from the best instructors & TA
# This content belongs to the following hierarchical headers path; H1: Data Engineering Bootcamp -> H2: LEARNING EXPERIENCE -> H4: Learn from the best instructors & TA
# This content belongs to the following hierarchical headers path; H1: Data Engineering Bootcamp -> H2: LEARNING EXPERIENCE -> H4: Learn from the best instructors & TA
# This content belongs to the following hierarchical headers path; H1: Data Engineering Bootcamp -> H2: LEARNING EXPERIENCE -> H4: Learn from the best instructors & TA
#
# ------------ Retrieval without filter ----------------
# --Question   :   Who are the instructors for the Data Engineering Bootcamp?
# This content belongs to the following hierarchical headers path; H2: Unlock Your Data Potential -> H3: Accepted -> H4: Scholarships
# This content belongs to the following hierarchical headers path; H2: Unlock Your Data Potential -> H3: Accepted -> H4: Career Services
# This content belongs to the following hierarchical headers path; H2: Join Data Science Bootcamp -> H4: Data Science Bootcamp -> H5: Bootcamp Application
# This content belongs to the following hierarchical headers path; H2: Unlock Your Data Potential -> H3: Accepted -> H4: Real-Client Project
# This content belongs to the following hierarchical headers path; H2: Join Data Science Bootcamp -> H4: Data Science Bootcamp -> H5: Bootcamp Application
# This content belongs to the following hierarchical headers path; H2: Corporate Training > -> H3: DevOps > -> H5: Resources

# %%
# Define the base template
template = """You are an intelligent chatbot.
Provide a detailed response to the question based on the provided context.
Refrain from inventing any information not explicitly stated in the context.
If uncertain, simply state that you do not know instead of speculating.
If you do not find the answer in the result, please state 'There is No answer.'
If there is 'pt' in path segment it means part-time and 'ft' in path segment it means full-time.
Based on the provided context and source documents, please generate a detailed and thorough answer to the question. 
Ensure that the response includes comprehensive explanations, relevant details, and is organized logically.
For example:
- If the question pertains to a weekly schedule and Daily Schedule, provide a detailed breakdown of activities for each day, organized by time.
- If the question pertains to instructors, you have to provide enumerately all names of instroctors and provide a detailed breakdown of all information.
- If the question involves a complex topic, break down the explanation into clear sections and subsections, covering all necessary aspects.
- Include examples, analogies, or case studies where applicable to enhance understanding.
- Address potential follow-up questions or related topics to provide a complete picture.
Please provide a well-structured, detailed, and insightful response.

Context: {context}
Question: {question}
Answer: """


# Define the QA chain prompt template
QA_CHAIN_PROMPT = PromptTemplate(
    input_variables=['question', 'context'],
    template = template
)

# %%
from langchain.retrievers import BM25Retriever, EnsembleRetriever
k=6
mmr1_retriever=db.as_retriever(search_kwargs={"k": 6}, search_type = 'mmr')
mmr2_retriever=db.as_retriever(search_kwargs={"k": 2}, search_type = 'similarity')
mmr3_retriever=db.as_retriever(search_kwargs={'k': k,'filter': {'hierarchical headers path': f'{closest_header}'}}, search_type = 'mmr')

bm25_retriever = BM25Retriever.from_documents(documents)
bm25_retriever.k = 4

ensemble_retriever = EnsembleRetriever(retrievers=[bm25_retriever, mmr1_retriever, mmr2_retriever,mmr3_retriever], weights=[0.5,0.5,0.5,0.5])

#docs = ensemble_retriever.get_relevant_documents(query=query)

qa_ENSEM = RetrievalQA.from_chain_type(llm= mistral_llm,
                                chain_type='stuff',
                                retriever= ensemble_retriever,
                                return_source_documents=True,
                                chain_type_kwargs={"prompt": QA_CHAIN_PROMPT}
                                 )


#result1 = qa_Rm.run(question=query, context=adjusted_context)
result_Ensemble = qa_ENSEM({"query": query})
response_Ensemble = result_Ensemble['result']  # The chatbot's response
source_documents_Ensemble = result_Ensemble['source_documents']  # The source documents used

print("\nQuestion---->>>",response_Ensemble.split("Question:")[1])
# Out:
# Question---->>>  Who are the instructors for the Data Engineering Bootcamp?
# Answer:
# The Data Engineering Bootcamp is taught by a team of highly skilled and experienced instructors. Some of the instructors include Stan Taov, a professional data engineer with hands-on experience in building, validating, and deploying machine learning models and creating end-to-end data pipelines. He is passionate about all things data and has a strong knowledge of converting business problems into analytical use cases. Indrani Gorti is a polyglot with experience in data engineering, data science, and solving business problems using ML and AI. She has worked in major industries like Finance, Telecommunications, Technology, Retail, and Startups. Her work has involved end-to-end projects from data ingestion, data analysis to the deployment of models in various setups using user transaction and interaction logs. She is a Director of Platform and ML engineering at Loblaw Digital. Other instructors include Zheng Xu, a data engineer at The Globe and Mail, and Edwin Guo, a big data specialist at CPPIB. The instructors have a passion for teaching and a wealth of real-world experiences in their respective fields, ensuring that students are learning from the best.
